# %%
import pandas as pd
df = pd.read_csv("./dataset/dataset.csv")

# %%
df.describe().transpose().to_csv("./dataset/feature.csv")

# %%
data = pd.read_csv("./dataset/feature.csv")
data
# Out:
#        Unnamed: 0      mean       std  min  25%  50%  75%  max
# 0             AGE  1.620690  0.613154    1    1    2    2    3
# 1          GENDER  1.600000  0.491596    1    1    2    2    2
# 2         HS_TYPE  1.944828  0.537216    1    2    2    2    3
# 3     SCHOLARSHIP  3.572414  0.805750    1    3    3    4    5
# 4            WORK  1.662069  0.474644    1    1    2    2    2
# 5        ACTIVITY  1.600000  0.491596    1    1    2    2    2
# 6         PARTNER  1.579310  0.495381    1    1    2    2    2
# 7          SALARY  1.627586  1.020245    1    1    1    2    5
# 8       TRANSPORT  1.620690  1.061112    1    1    1    2    4
# 9          LIVING  1.731034  0.783999    1    1    2    2    4
# 10     MOTHER_EDU  2.282759  1.223062    1    1    2    3    6
# 11     FATHER_EDU  2.634483  1.147544    1    2    3    3    6
# 12     #_SIBLINGS  2.806897  1.360640    1    2    3    4    5
# 13           KIDS  1.172414  0.490816    1    1    1    1    3
# ...
